# %% [markdown]
# # The Code

# %%
import pandas as pd;
column_map = { 'date': 'Date','IoE':'Income/Expenses', 'category':'Category', 'memo': 'Memo', 'amount':'Amount'};
column_keys = list(column_map.keys());
print(column_keys)
# Out:
# ['date', 'IoE', 'category', 'memo', 'amount']

# %%
data = pd.read_csv("data.csv",delimiter = ',');
yearWiseData =[];

# %%
from datetime import date

def getDate(str):
    date_tokenized = str.split('-')
    return date(int(date_tokenized[0]), int(date_tokenized[1]), int(date_tokenized[2]))

# %%
def getCategories():
    return data[column_map['category']].unique()

print(getCategories());
# Out:
# ['Food' 'home bills' 'Transportation' 'Refunds' 'Home' 'Gift' 'Education'
#  'Travel' 'Social' 'mumbai groceries' 'mumbai flat' 'Electronics'
#  'during work snack' 'lend return' 'Others' 'Shopping' 'Car' 'petrol'
#  'Wine' 'pocket money' 'Health' 'Cigarette' 'Office' 'lend' 'Bills'
#  'Clothing' 'carry on' 'carry on to next month' 'Grants' 'Telephone']

# %%
def mergeDailyExpenseData(data):
    unique_dates = data[column_map['date']].unique()
    #print(len(unique_dates))
    #print(data.loc[data['Date'] == '2019-11-14'])
    
    daily = []
    #expense = data.loc[data['Amount']<0]
    #expense = data;
    for unique_date in unique_dates:
        
        categories = data.loc[data['Date'] == unique_date][column_map['category']].unique();
        l='';
        for c in categories:
            l = l+',' + c;
        l= l[1:];
        memos = data.loc[data['Date'] == unique_date][column_map['memo']].unique();
        s='';
        for c in memos:
            s = s+',' +str(c);
        s= s[1:];
        daily.append({'Date': unique_date, 'Category': l, 'Memo': s, 'Amount': -1*np.sum(data.loc[data['Date'] == unique_date][column_map['amount']].values)});
        
    return pd.DataFrame.from_dict(daily, orient='columns');

# %%
def getDataForColumns(data, column_bitmask, fromDate, toDate, mergeDailyData):
    columns = [];
    
    for i in range(len(column_bitmask)):
        if column_bitmask[i] == 1:
            columns.append(column_map[column_keys[i]]);
    
    if mergeDailyData == True:
        df = mergeDailyExpenseData(data);
        if fromDate == '' and toDate == '':
            return df
    
        fromDate = getDate(fromDate);
        toDate = getDate(toDate);

        for index, row in df.iterrows():
            currDate = getDate(row[column_map['date']]);
            if currDate < fromDate or currDate > toDate:
                df.drop(index, inplace=True)

        return df[columns].copy();
    
    
    df = data[columns].copy();
        
    if fromDate == '' and toDate == '':
        return df
    
    fromDate = getDate(fromDate);
    toDate = getDate(toDate);
    
    for index, row in df.iterrows():
        currDate = getDate(row[column_map['date']]);
        if currDate < fromDate or currDate > toDate:
            df.drop(index, inplace=True)
    return df;

# %%
def getDataForCategory(data, category, fromDate, toDate, isMergeData):
    frame = getDataForColumns(data, [1, 1, 1, 1, 1], fromDate, toDate, isMergeData)    
    if category == '':
        return frame;
    #frame = frame[frame.Category == category]
    for index, row in frame.iterrows():
        if category not in row[column_map['category']]:
            frame.drop(index, inplace=True)
    return frame;

# %% [markdown]
# ### Visualisation functions

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_style("darkgrid")

def createBarPlot(x, y, x_dim, y_dim):
    plt.figure(figsize=(x_dim, y_dim))
    plt.xlabel('xlabel', fontsize=3)
    plt.xticks(rotation=90)
    plt.bar(x,y)
    plt.show()
    
def createLinePlot(x, y, x_dim, y_dim):
    plt.figure(figsize=(x_dim, y_dim))
    plt.xlabel('xlabel', fontsize=3)
    plt.xticks(rotation=90)
    plt.plot(x,y)
    plt.show()
    
def createBubblePlot(x, y, z, x_dim, y_dim):
    plt.figure(figsize=(x_dim, y_dim))
    plt.scatter(x, y, s=z*2000, c=x, cmap="Blues", alpha=0.4, edgecolors="grey", linewidth=2)
 
    # Add titles (main and on axis)
    plt.xlabel("the X axis")
    plt.ylabel("the Y axis")
    plt.title("A colored bubble plot")

    plt.show()

# %%
def showResult(dic):
    hr =      '###############################################################\n'
    keys = list(dic.keys());
    values = list(dic.values());
    
    if 'Title' not in keys:
        dic['Title'] = 'Title not specified'; 
        keys.append('Title')
        values.append('Title not specified')
    
    result = '';
    
    heading = '#              '+dic['Title'].upper()+'\n'
    
    result+=hr;
    result+=heading;
    
    for i in range(len(keys)):
        if keys[i] != 'Title':
            result+= '# '+keys[i]+' : '+str(values[i])+'\n'
    print(result+hr);

# %%
import numpy as np

def getTotalExpenditure(data):
    
    result={};
    category_expenses = [];
    startDate = data['Date'].iloc[-1] # first element 
    endDate = data['Date'].iloc[0] # last element 
    categoricalExpenditure = [];
    for category in getCategories():
        category_data = getDataForCategory(data, category, '', '', False);
        
        category_expense = category_data[column_map['amount']].values;
        category_expenses.append(-1*np.sum(category_expense));
        dates = category_data[column_map['date']].values
        if(len(dates)!=0):
            first = getDate(dates[len(dates)-1])
            last = getDate(dates[0])
            categoricalExpenditure.append({'category':category, 'startDate': first, 'lastDate': last, 'expense': -1*np.sum(category_expense), 'data': category_data});

    result['Expense'] = category_expenses;
    result['categoricalExpenditure'] = categoricalExpenditure;
    return result;

# %%
def getUniqueYears():
    unique_dates = data[column_map['date']].unique()

    unique_years = np.empty(len(unique_dates))
    
    for index in range(len(unique_dates)):
        unique_years[index] = str(getDate(unique_dates[index]).year)
        
    return np.unique(unique_years)

# %%
def getYearlyData():

    unique_years = getUniqueYears()
    #print(unique_years)
    yearly_data = [];
    
    df = data.copy();
    for year in unique_years:
        
        yearly = [];
        for index, row in df.iterrows():
            currYear = getDate(row[column_map['date']]).year;
            if currYear == year:
                yearly.append(row);
                df.drop(index, inplace=True)
                
                
        yearly_data.append({'year': currYear, 'data': pd.DataFrame(yearly, columns = column_map.values())})

    return yearly_data

# %%
def getDataForYear(year):
    global yearWiseData
    if len(yearWiseData) == 0:
        yearWiseData = getYearlyData();
        
    for yearly in yearWiseData:
        if yearly['year'] == year:
            return yearly['data'];
        
    #if data for year does not exist
    return pd.DataFrame(columns=column_map.values())

# %%
import calendar;

def getMonthlyData():
    
    monthly_data = []
    global yearWiseData
    unique_years = getUniqueYears();
    for year in unique_years:
        yearlyData = getDataForYear(year)
        
        unique_dates = yearlyData[column_map['date']].unique()
        unique_months = np.empty(len(unique_dates))

        for index in range(len(unique_dates)):
            unique_months[index] = str(getDate(unique_dates[index]).month)

        unique_months = np.unique(unique_months)
        
        for month in unique_months:
            m='';
            if(month < 10):
                m = '0'+str(int(month));
            else:
                m = str(int(month))
            
            year = int (year)
            startDate = str(year)+'-'+str(m)+'-01';
            endDate = str(year)+'-'+str(m)+'-'+ str(int(calendar.monthrange(int(year),int(month))[1]))
            monthly_data.append({'monthStart': startDate, 'monthEnd': endDate, 'data':getDataForCategory(yearlyData, '', startDate, endDate, False)});
    return monthly_data;
# Out:
# Days:  30 days, 0:00:00
# Expense for category Food :  5619.0
# ###############################################################
# Days:  4 days, 0:00:00
# Expense for category home bills :  1830.0
# ###############################################################
# Days:  23 days, 0:00:00
# Expense for category Transportation :  3230.0
# ###############################################################
# Days:  0:00:00
# Expense for category Home :  30.0
# ###############################################################
# Days:  1 day, 0:00:00
# Expense for category Gift :  12000.0
# ###############################################################
# Days:  0:00:00
# Expense for category Education :  350.0
# ###############################################################
# Days:  13 days, 0:00:00
# Expense for category mumbai flat :  7350.0
# ###############################################################
# Days:  8 days, 0:00:00
# Expense for category Others :  900.0
# ###############################################################
# Days:  0:00:00
# Expense for category Shopping :  3350.0
# ###############################################################
# Days:  0:00:00
# Expense for category Car :  100.0
# ###############################################################
# Days:  20 days, 0:00:00
# Expense for category petrol :  400.0
# ###############################################################
# Days:  22 days, 0:00:00
# Expense for category Wine :  3815.0
# ###############################################################
# Days:  6 days, 0:00:00
# Expense for category pocket money :  -1600.0
# ###############################################################
# Days:  3 days, 0:00:00
# Expense for category Health :  220.0
# ###############################################################
# Days:  0:00:00
# Expense for category Cigarette :  30.0
# ###############################################################
# Days:  0:00:00
# Expense for category Office :  10.0
# ###############################################################
#
#     ###############################################################
#     #                                                             #
#     #                     Total expenditure Data:                 #
#     #         Start date: 2019-10-31                                      #
#     #         End Date: 2019-10-01                                        #
#     #         Money flow: 37634.0                                      #
#     #                                                             #
#     ###############################################################

# %%
#print(getDataForCategory(data, 'Transportation', ' 2019-10-01', ' 2019-10-30', False));

# %% [markdown]
#  # Data & Visualisations

# %% [markdown]
# ## Total expenditures data

# %%
categorical_expenditure = getTotalExpenditure(data)
showResult({'Title': 'All Time Categorical Expenditure', 'Expense': -1*np.sum(categorical_expenditure['Expense'])});
ce = categorical_expenditure['categoricalExpenditure'];

print(ce)

categories = []
expenses = []

#{'category':category, 'startDate': first, 'lastDate': last, 'expense': -1*np.sum(category_expense), 'data': category_data}
for c in ce:
    #showResult({'Title': 'Category: '+c['category'], 'Days: ':c['lastDate']-c['startDate'],'Expense': c['expense']});
    categories.append(c['category']);
    expenses.append(c['expense']);
    
createBarPlot(categories, expenses, 10,10)
# Out:
# ###############################################################
# #              ALL TIME CATEGORICAL EXPENDITURE
# # Expense : -90910.09
# ###############################################################
#
# [{'category': 'Food', 'startDate': datetime.date(2018, 11, 20), 'lastDate': datetime.date(2019, 11, 15), 'expense': 22622.98, 'data':            Date Category                           Memo  Amount
# 0    2019-11-15     Food                         coffee  -70.00
# 2    2019-11-14     Food                          Lunch  -60.00
# 3    2019-11-14     Food                      breakfast  -19.00
# 4    2019-11-14     Food                   water bottle  -20.00
# 5    2019-11-14     Food                      ice cream  -40.00
# 6    2019-11-14     Food                       shawarma  -70.00
# 8    2019-11-13     Food                         dinner  -80.00
# 9    2019-11-13     Food                          lunch  -60.00
# 10   2019-11-13     Food                      breakfast  -19.00
# 11   2019-11-12     Food                         dinner -100.00
# 12   2019-11-12     Food                          lunch  -45.00
# 13   2019-11-12     Food                      breakfast  -19.00
# 14   2019-11-11     Food                         dinner  -50.00
# 15   2019-11-11     Food                          lunch  -50.00
# 21   2019-11-10     Food                         coffee  -40.00
# 31   2019-11-07     Food                          lunch  -45.00
# 32   2019-11-07     Food                      breakfast  -25.00
# 38   2019-11-06     Food                          lunch  -60.00
# 39   2019-11-06     Food                      breakfast  -25.00
# 41   2019-11-05     Food                          Lunch  -45.00
# 42   2019-11-05     Food                        biryani -140.00
# 49   2019-11-04     Food                          lunch  -60.00
# 52   2019-11-03     Food                      breakfast  -35.00
# 55   2019-11-01     Food                        shwarma  -70.00
# 56   2019-11-01     Food                          lunch  -60.00
# 57   2019-11-01     Food                          chips  -10.00
# 58   2019-10-31     Food                          lunch  -45.00
# 59   2019-10-31     Food                      breakfast  -19.00
# 60   2019-10-31     Food                     bhurji pav  -25.00
# 61   2019-10-28     Food                     Bois lassi -130.00
# ..          ...      ...                            ...     ...
# 370  2019-01-31     Food                         burger  -40.00
# 376  2019-01-29     Food                   crazy cheesy -220.00
# 379  2019-01-23     Food                            McD -100.00
# 385  2018-12-30     Food                  McD breakfast -230.00
# 386  2018-12-29     Food                           cafe -100.00
# 389  2018-12-21     Food  juice (avani, deepika, Bajaj)  -65.00
# 390  2018-12-20     Food              sabudana khichadi  -25.00
# 391  2018-12-19     Food                      pani puri  -15.00
# 398  2018-12-17     Food                            McD  -81.98
# 399  2018-12-16     Food                          party -310.00
# 400  2018-12-14     Food          amruteshwar breakfast  -40.00
# 403  2018-12-14     Food                          lunch  -45.00
# 404  2018-12-14     Food                      breakfast  -10.00
# 405  2018-12-13     Food                         dinner -130.00
# 406  2018-12-13     Food                          bread  -30.00
# 407  2018-12-12     Food                           eggs  -60.00
# 408  2018-12-11     Food                    Burger+coke -115.00
# 410  2018-12-09     Food                            McD  -85.00
# 411  2018-12-08     Food                           Appy  -10.00
# 413  2018-12-06     Food                         Coffee  -25.00
# 415  2018-12-05     Food                            NPB -110.00
# 418  2018-12-04     Food                          pizza  -80.00
# 420  2018-12-01     Food                           coke  -40.00
# 421  2018-12-01     Food                            NaN -100.00
# 423  2018-12-01     Food                    gobi manchu  -20.00
# 426  2018-11-29     Food       vada pav and sabudanvada  -45.00
# 427  2018-11-24     Food                 snacks + lunch -154.00
# 429  2018-11-22     Food               chips for abhyas  -25.00
# 431  2018-11-21     Food                           coke  -66.00
# 433  2018-11-20     Food                gobi manchurian  -20.00
#
# [227 rows x 4 columns]}, {'category': 'home bills', 'startDate': datetime.date(2019, 9, 8), 'lastDate': datetime.date(2019, 11, 15), 'expense': 8327.0, 'data':            Date    Category     Memo  Amount
# 1    2019-11-15  home bills     wifi -5985.0
# 83   2019-10-22  home bills     mseb -1420.0
# 96   2019-10-18  home bills  aai jio  -410.0
# 248  2019-09-08  home bills      NaN  -512.0}, {'category': 'Transportation', 'startDate': datetime.date(2019, 8, 5), 'lastDate': datetime.date(2019, 11, 14), 'expense': 9922.0, 'data':            Date        Category                     Memo  Amount
# 7    2019-11-14  Transportation                  to Pune  -390.0
# 16   2019-11-11  Transportation                to office   -10.0
# 23   2019-11-09  Transportation                to Mumbai  -525.0
# 29   2019-11-08  Transportation                     home  -152.0
# 35   2019-11-06  Transportation                  to Pune  -190.0
# 50   2019-11-04  Transportation                to office   -10.0
# 53   2019-11-02  Transportation                 shivneri  -525.0
# 54   2019-11-01  Transportation                     home  -390.0
# 62   2019-10-27  Transportation                 shivneri  -525.0
# 75   2019-10-24  Transportation                  to Pune  -400.0
# 82   2019-10-22  Transportation                to office   -10.0
# 90   2019-10-20  Transportation                to Mumbai  -525.0
# 95   2019-10-18  Transportation                  to Pune  -390.0
# 98   2019-10-18  Transportation                to office   -23.0
# 114  2019-10-14  Transportation                to office   -10.0
# 118  2019-10-13  Transportation                to Mumbai  -422.0
# 122  2019-10-11  Transportation                  to home  -320.0
# 138  2019-10-07  Transportation                      NaN   -10.0
# 141  2019-10-05  Transportation                 shivneri  -525.0
# 143  2019-10-04  Transportation                  to ghar   -30.0
# 146  2019-10-04  Transportation                 to Dadar   -10.0
# 147  2019-10-04  Transportation              to Vikhroli   -30.0
# 167  2019-09-30  Transportation                      NaN   -10.0
# 171  2019-09-28  Transportation                 shivneri  -525.0
# 174  2019-09-27  Transportation                  to home   -40.0
# 175  2019-09-27  Transportation          to shivajinagar  -300.0
# 176  2019-09-27  Transportation                 to dadar   -70.0
# 177  2019-09-27  Transportation               to vikroli   -30.0
# 180  2019-09-26  Transportation                      NaN   -23.0
# 192  2019-09-23  Transportation                      NaN   -10.0
# 198  2019-09-21  Transportation                 shivneri  -525.0
# 199  2019-09-20  Transportation                  to Pune  -300.0
# 200  2019-09-20  Transportation                 to dadar  -100.0
# 213  2019-09-18  Transportation                 rickshaw   -22.0
# 221  2019-09-16  Transportation                      NaN   -10.0
# 226  2019-09-14  Transportation                 shivneri  -525.0
# 231  2019-09-11  Transportation              to swargate  -350.0
# 232  2019-09-11  Transportation               to vikroli   -30.0
# 233  2019-09-11  Transportation                 to dadar   -70.0
# 236  2019-09-11  Transportation                 rickshaw   -30.0
# 245  2019-09-09  Transportation           IIT to Xoriant   -36.0
# 255  2019-09-01  Transportation       shivneri to Mumbai  -526.0
# 257  2019-08-31  Transportation                shivshahi  -290.0
# 258  2019-08-31  Transportation         rickshaw vandana   -28.0
# 260  2019-08-31  Transportation  till Mulund Rly station   -20.0
# 261  2019-08-31  Transportation            IIT main gate   -30.0
# 262  2019-08-31  Transportation                     ghar   -50.0
# 292  2019-08-09  Transportation                      cab  -230.0
# 296  2019-08-07  Transportation                 rickshaw  -120.0
# 301  2019-08-05  Transportation                      cab  -200.0}, {'category': 'Refunds', 'startDate': datetime.date(2019, 11, 10), 'lastDate': datetime.date(2019, 11, 10), 'expense': -128.0, 'data':           Date Category   Memo  Amount
# 17  2019-11-10  Refunds  raddi   128.0}, {'category': 'Home', 'startDate': datetime.date(2019, 9, 6), 'lastDate': datetime.date(2019, 11, 10), 'expense': 1480.0, 'data':            Date Category               Memo  Amount
# 18   2019-11-10     Home       dry cleaning  -126.0
# 19   2019-11-10     Home      aavala supari   -50.0
# 86   2019-10-21     Home         buttermilk   -30.0
# 169  2019-09-28     Home            grocery  -142.0
# 224  2019-09-15     Home  2kg Sugar+1L milk  -132.0
# 252  2019-09-06     Home         rent token -1000.0}, {'category': 'Gift', 'startDate': datetime.date(2018, 12, 29), 'lastDate': datetime.date(2019, 11, 10), 'expense': 17414.0, 'data':            Date Category                        Memo   Amount
# 20   2019-11-10     Gift  Chitale pedhe Deepak Verma   -240.0
# 63   2019-10-27     Gift             maau chocolates    -20.0
# 67   2019-10-26     Gift                 Didi mobile -11980.0
# 165  2019-09-30     Gift                       ujwal  -1750.0
# 229  2019-09-13     Gift            Puru double mint    -10.0
# 283  2019-08-13     Gift                    boo gift  -2300.0
# 387  2018-12-29     Gift               Neha birthday  -1114.0}, {'category': 'Education', 'startDate': datetime.date(2018, 12, 8), 'lastDate': datetime.date(2019, 11, 9), 'expense': 1090.0, 'data':            Date   Category                Memo  Amount
# 22   2019-11-09  Education        udemy course  -720.0
# 156  2019-10-02  Education         convocation  -350.0
# 412  2018-12-08  Education  Stationary: 2 pens   -20.0}, {'category': 'Travel', 'startDate': datetime.date(2019, 3, 16), 'lastDate': datetime.date(2019, 11, 8), 'expense': 3646.8900000000003, 'data':            Date Category                  Memo   Amount
# 24   2019-11-08   Travel            train food   -30.00
# 25   2019-11-08   Travel  station parking Neha   -10.00
# 26   2019-11-08   Travel             breakfast   -30.00
# 27   2019-11-08   Travel              sandwich   -60.00
# 28   2019-11-08   Travel                 lunch  -500.00
# 34   2019-11-06   Travel                 hotel -1609.00
# 36   2019-11-06   Travel         bus to Sangli  -749.70
# 37   2019-11-06   Travel       train to Sangli  -403.19
# 337  2019-03-18   Travel              rickshaw   -50.00
# 339  2019-03-18   Travel                   cab  -200.00
# 345  2019-03-16   Travel                     T    -5.00}, {'category': 'Social', 'startDate': datetime.date(2018, 12, 17), 'lastDate': datetime.date(2019, 11, 7), 'expense': 5721.0, 'data':            Date Category           Memo  Amount
# 30   2019-11-07   Social            cds  -300.0
# 253  2019-09-02   Social    KPT wargani  -301.0
# 281  2019-08-14   Social  sangli floods -5000.0
# 395  2018-12-17   Social            NaN  -120.0}, {'category': 'mumbai groceries', 'startDate': datetime.date(2019, 11, 5), 'lastDate': datetime.date(2019, 11, 6), 'expense': 115.56, 'data':           Date          Category               Memo  Amount
# 33  2019-11-06  mumbai groceries                NaN  -30.00
# 45  2019-11-05  mumbai groceries  Maggie and butter  -85.56}, {'category': 'mumbai flat', 'startDate': datetime.date(2019, 10, 3), 'lastDate': datetime.date(2019, 11, 5), 'expense': 15059.0, 'data':            Date     Category             Memo  Amount
# 40   2019-11-05  mumbai flat             rent -7000.0
# 44   2019-11-05  mumbai flat        scissorrs  -129.0
# 47   2019-11-05  mumbai flat             maid  -200.0
# 48   2019-11-05  mumbai flat       light bill  -380.0
# 104  2019-10-16  mumbai flat  zaadu and stuff  -100.0
# 134  2019-10-07  mumbai flat             rent -7000.0
# 150  2019-10-03  mumbai flat             maid  -250.0}, {'category': 'Electronics', 'startDate': datetime.date(2019, 11, 5), 'lastDate': datetime.date(2019, 11, 5), 'expense': 849.0, 'data':           Date     Category     Memo  Amount
# 43  2019-11-05  Electronics  trimmer  -849.0}, {'category': 'during work snack', 'startDate': datetime.date(2019, 9, 10), 'lastDate': datetime.date(2019, 11, 5), 'expense': 95.0, 'data':            Date           Category           Memo  Amount
# 46   2019-11-05  during work snack  Office chakna   -60.0
# 237  2019-09-10  during work snack            NaN   -25.0
# 238  2019-09-10  during work snack            NaN   -10.0}, {'category': 'lend return', 'startDate': datetime.date(2018, 12, 17), 'lastDate': datetime.date(2019, 11, 3), 'expense': -3039.67, 'data':            Date     Category     Memo   Amount
# 51   2019-11-03  lend return   Sharee  3000.00
# 396  2018-12-17  lend return  McD boo    39.67}, {'category': 'Others', 'startDate': datetime.date(2018, 11, 22), 'lastDate': datetime.date(2019, 10, 27), 'expense': 5135.49, 'data':            Date Category                  Memo   Amount
# 65   2019-10-27   Others                   KPT  -100.00
# 84   2019-10-22   Others              pot luck  -200.00
# 93   2019-10-19   Others               license  -600.00
# 218  2019-09-17   Others           kapde saban   -10.00
# 222  2019-09-16   Others      beard growth oil  -382.00
# 247  2019-09-08   Others     Dhol maintainance  -200.00
# 271  2019-08-20   Others           activa tire  -830.00
# 286  2019-08-12   Others               laundry   -55.00
# 294  2019-08-07   Others  Kaustubh chi udhaari -1000.00
# 298  2019-08-06   Others                  vics    -5.00
# 326  2019-03-24   Others         Attari border   -40.00
# 328  2019-03-24   Others                  kada   -30.00
# 335  2019-03-19   Others                solang -1250.00
# 342  2019-03-17   Others                    Tr   -10.00
# 348  2019-02-22   Others                  neha  -110.00
# 354  2019-02-12   Others              pen+glue    -8.00
# 357  2019-02-11   Others          Neha chicken  -240.00
# 358  2019-02-11   Others                photos   -80.00
# 359  2019-02-11   Others      found in my self   500.00
# 360  2019-02-04   Others                 tires    -5.00
# 365  2019-02-02   Others              charcoal   -75.00
# 377  2019-01-25   Others        food + sinhgad  -300.00
# 388  2018-12-24   Others                  trip    -5.00
# 397  2018-12-17   Others               haircut  -120.00
# 417  2018-12-05   Others                   NaN    20.00
# 428  2018-11-22   Others        boo chingu ahe    -0.49}, {'category': 'Shopping', 'startDate': datetime.date(2019, 8, 7), 'lastDate': datetime.date(2019, 10, 25), 'expense': 4349.0, 'data':            Date  Category                Memo  Amount
# 68   2019-10-25  Shopping  aai and aaji saadi -3350.0
# 295  2019-08-07  Shopping           earphones  -999.0}, {'category': 'Car', 'startDate': datetime.date(2019, 3, 26), 'lastDate': datetime.date(2019, 10, 25), 'expense': 450.0, 'data':            Date Category             Memo  Amount
# 69   2019-10-25      Car  activa puncture  -100.0
# 323  2019-03-26      Car   Panvel to pune  -350.0}, {'category': 'petrol', 'startDate': datetime.date(2018, 11, 21), 'lastDate': datetime.date(2019, 10, 25), 'expense': 4035.0, 'data':            Date Category    Memo  Amount
# 70   2019-10-25   petrol     NaN  -200.0
# 140  2019-10-05   petrol     NaN  -200.0
# 195  2019-09-22   petrol     NaN  -200.0
# 250  2019-09-07   petrol     NaN  -200.0
# 269  2019-08-21   petrol     NaN  -100.0
# 275  2019-08-19   petrol     NaN  -200.0
# 279  2019-08-14   petrol     NaN  -200.0
# 300  2019-08-06   petrol     NaN  -200.0
# 310  2019-05-14   petrol     NaN  -100.0
# 313  2019-05-10   petrol     NaN  -200.0
# 316  2019-05-04   petrol     NaN  -200.0
# 349  2019-02-19   petrol     NaN  -200.0
# 353  2019-02-12   petrol     NaN  -200.0
# 361  2019-02-04   petrol     NaN  -200.0
# 374  2019-01-29   petrol     PUC   -35.0
# 375  2019-01-29   petrol  petrol  -200.0
# 378  2019-01-24   petrol     NaN  -200.0
# 380  2019-01-16   petrol     NaN  -200.0
# 381  2019-01-06   petrol     NaN  -200.0
# 392  2018-12-19   petrol     NaN  -200.0
# 414  2018-12-06   petrol     NaN  -200.0
# 432  2018-11-21   petrol  petrol  -200.0}, {'category': 'Wine', 'startDate': datetime.date(2019, 3, 17), 'lastDate': datetime.date(2019, 10, 25), 'expense': 10344.0, 'data':            Date Category         Memo  Amount
# 71   2019-10-25     Wine           BB -1083.0
# 119  2019-10-13     Wine           BB  -581.0
# 142  2019-10-05     Wine           BB -1921.0
# 153  2019-10-03     Wine         beer  -230.0
# 170  2019-09-28     Wine           BB -1274.0
# 196  2019-09-22     Wine           BB  -470.0
# 225  2019-09-14     Wine          NaN  -506.0
# 227  2019-09-13     Wine          FML  -638.0
# 263  2019-08-30     Wine          NaN  -220.0
# 266  2019-08-22     Wine          FML  -378.0
# 278  2019-08-18     Wine  bid Capital  -730.0
# 280  2019-08-14     Wine          NaN  -773.0
# 290  2019-08-10     Wine    Broasters  -440.0
# 291  2019-08-09     Wine          FML  -500.0
# 329  2019-03-23     Wine          NaN  -200.0
# 340  2019-03-17     Wine          NaN  -400.0}, {'category': 'pocket money', 'startDate': datetime.date(2018, 11, 20), 'lastDate': datetime.date(2019, 10, 25), 'expense': -27098.0, 'data':            Date      Category                              Memo   Amount
# 72   2019-10-25  pocket money                               NaN    600.0
# 94   2019-10-19  pocket money                               NaN   1000.0
# 320  2019-05-01  pocket money                               NaN   4000.0
# 347  2019-03-15  pocket money  5k acc + 4k cash +(1090+17) self  10107.0
# 371  2019-01-31  pocket money                               NaN   4000.0
# 382  2019-01-04  pocket money                               NaN   3000.0
# 409  2018-12-11  pocket money                               NaN    180.0
# 416  2018-12-05  pocket money                             asach    200.0
# 419  2018-12-02  pocket money                               NaN   3000.0
# 430  2018-11-22  pocket money                               NaN    398.0
# 434  2018-11-20  pocket money                               NaN    613.0}, {'category': 'Health', 'startDate': datetime.date(2019, 10, 12), 'lastDate': datetime.date(2019, 10, 15), 'expense': 220.0, 'data':            Date Category   Memo  Amount
# 107  2019-10-15   Health  golya  -210.0
# 120  2019-10-12   Health   vics   -10.0}, {'category': 'Cigarette', 'startDate': datetime.date(2019, 10, 13), 'lastDate': datetime.date(2019, 10, 13), 'expense': 30.0, 'data':            Date   Category         Memo  Amount
# 116  2019-10-13  Cigarette  Rohya sutta   -30.0}, {'category': 'Office', 'startDate': datetime.date(2019, 2, 12), 'lastDate': datetime.date(2019, 10, 1), 'expense': 35.0, 'data':            Date Category             Memo  Amount
# 162  2019-10-01   Office              pen   -10.0
# 355  2019-02-12   Office  documents Xerox   -25.0}, {'category': 'lend', 'startDate': datetime.date(2018, 11, 30), 'lastDate': datetime.date(2019, 11, 3), 'expense': 1717.33, 'data':            Date     Category                 Memo   Amount
# 51   2019-11-03  lend return               Sharee  3000.00
# 210  2019-09-18         lend      yash buttermilk   -12.00
# 254  2019-09-01         lend                Sharu -4000.00
# 277  2019-08-18         lend                Tapan  -150.00
# 332  2019-03-22         lend              sampada   -40.00
# 384  2018-12-30         lend  tapan McD breakfast  -230.00
# 394  2018-12-18         lend                 neha  -200.00
# 396  2018-12-17  lend return              McD boo    39.67
# 401  2018-12-14         lend          sumeet/food   -45.00
# 402  2018-12-14         lend         Deepika/food   -10.00
# 425  2018-11-30         lend              to neha   -70.00}, {'category': 'Bills', 'startDate': datetime.date(2019, 3, 19), 'lastDate': datetime.date(2019, 9, 9), 'expense': 2052.0, 'data':            Date Category              Memo  Amount
# 244  2019-09-09    Bills          Vodafone  -511.0
# 282  2019-08-14    Bills            airtel  -512.0
# 318  2019-05-02    Bills           aai Jio  -399.0
# 319  2019-05-02    Bills            airtel  -512.0
# 334  2019-03-19    Bills  atm service rent  -118.0}, {'category': 'Clothing', 'startDate': datetime.date(2019, 3, 22), 'lastDate': datetime.date(2019, 9, 7), 'expense': 650.0, 'data':            Date  Category               Memo  Amount
# 249  2019-09-07  Clothing  zabba+odhni+baali  -540.0
# 331  2019-03-22  Clothing       dry cleaning  -110.0}, {'category': 'carry on', 'startDate': datetime.date(2018, 11, 30), 'lastDate': datetime.date(2019, 2, 1), 'expense': -0.0, 'data':            Date                Category Memo   Amount
# 369  2019-02-01                carry on  NaN  5547.00
# 372  2019-01-31  carry on to next month  NaN -5547.00
# 422  2018-12-01                carry on  NaN   430.51
# 424  2018-11-30  carry on to next month  NaN  -430.51}, {'category': 'carry on to next month', 'startDate': datetime.date(2018, 11, 30), 'lastDate': datetime.date(2019, 1, 31), 'expense': 5977.51, 'data':            Date                Category Memo   Amount
# 372  2019-01-31  carry on to next month  NaN -5547.00
# 424  2018-11-30  carry on to next month  NaN  -430.51}, {'category': 'Grants', 'startDate': datetime.date(2018, 12, 19), 'lastDate': datetime.date(2019, 1, 30), 'expense': -620.0, 'data':            Date Category                 Memo  Amount
# 373  2019-01-30   Grants  birthday(from aaji)   500.0
# 393  2018-12-19   Grants            mami+aaji   120.0}, {'category': 'Telephone', 'startDate': datetime.date(2019, 1, 2), 'lastDate': datetime.date(2019, 1, 2), 'expense': 458.0, 'data':            Date   Category      Memo  Amount
# 383  2019-01-02  Telephone  Vodafone  -458.0}]

# %% [markdown]
# ## Monthly expenditures

# %%
monthly_expenditure = getMonthlyData()
for month in monthly_expenditure:
    categorical_expenditure = getTotalExpenditure(month['data']);
    ce = categorical_expenditure['categoricalExpenditure'];
    
    categories = []
    expenses = []

    #{'category':category, 'startDate': first, 'lastDate': last, 'expense': -1*np.sum(category_expense), 'data': category_data}
    for c in ce:
        #showResult({'Title': 'Category: '+c['category'], 'Days: ':c['lastDate']-c['startDate'],'Expense': c['expense']});
        categories.append(c['category']);
        expenses.append(c['expense']);
    m_split = month['monthStart'].split('-')
    print('For Month: ',m_split[1],' Year: ', m_split[0])
    createBarPlot(categories, expenses, 5,5)
# Out:
# For Month:  11  Year:  2018
# For Month:  12  Year:  2018
# For Month:  01  Year:  2019
# For Month:  02  Year:  2019
# For Month:  03  Year:  2019
# For Month:  05  Year:  2019
# For Month:  08  Year:  2019
# For Month:  09  Year:  2019
# For Month:  10  Year:  2019
# For Month:  11  Year:  2019

# %% [markdown]
# ## Custom Queries

# %% [markdown]
# ### Get Data For Individual categories

# %%
print('Following are the categories')
print(getCategories())
# Out:
# Following are the categories
# ['Food' 'home bills' 'Transportation' 'Refunds' 'Home' 'Gift' 'Education'
#  'Travel' 'Social' 'mumbai groceries' 'mumbai flat' 'Electronics'
#  'during work snack' 'lend return' 'Others' 'Shopping' 'Car' 'petrol'
#  'Wine' 'pocket money' 'Health' 'Cigarette' 'Office' 'lend' 'Bills'
#  'Clothing' 'carry on' 'carry on to next month' 'Grants' 'Telephone']

# %%
print(np.sum(getTotalExpenditure(getDataForCategory(data, 'Transportation', '2019-08-26', '2019-11-15', False))['Expense']))
# Out:
# 9372.0

# %% [markdown]
# ### Food expenditure other than the essential breakfast, lunch, freakfast

# %%
dataa = getDataForCategory(data, 'Food', '2019-08-26', '2019-11-30', False)
for index, row in dataa.iterrows():
    row['Memo'] = str(row['Memo']).lower()
    if row['Memo'] in ['lunch', 'breakfast', 'dinner']:
        dataa.drop(index, inplace=True)
        
print(-1*np.sum(getTotalExpenditure(getDataForCategory(dataa, '', '', '', False))['categoricalExpenditure'][0]['data']['Amount'].values)/3)
# Out:
# 1500.6666666666667

# %% [markdown]
# ### Average for category between dates

# %%
dataa = getDataForCategory(data, '', '2019-11-01', '2019-11-16', False)
#Averave
print(-1*np.sum(getTotalExpenditure(getDataForCategory(dataa, '', '', '', False))['categoricalExpenditure'][0]['data']['Amount'].values)/16)
# Out:
# 82.3125

# %% [markdown]
# ### Comparing a category on a monthly basis

# %%
monthly_data = getMonthlyData()

months = [];
expense = [] 

for monthly in monthly_data:
    monthly['data'] = getDataForCategory(monthly['data'], 'Wine', '', '', False)
    monthly['expense'] = -1*np.sum(monthly['data'][column_map['amount']].values)
    months.append(monthly['monthStart'].split('-')[1])
    expense.append(monthly['expense'])

print('Average: ', np.sum(np.array(expense))/len(months))
createBarPlot(months, expense, 8, 8);
# Out:
# Average:  1034.4

# %% [markdown]
# ### Comparing monthly line plots for a category

# %%
import calendar;

monthly_data = getMonthlyData()

for monthly in monthly_data:
    monthly['data'] = getDataForCategory(monthly['data'], 'Transportation', '', '', False)
    
    monthly['data'] = mergeDailyExpenseData(monthly['data'])
    #print(monthly['data'])
    monthStart = monthly['monthStart'].split('-');
    
    daysInAMonth = calendar.monthrange(int(monthStart[0]), int(monthStart[1]))[1];
    
    if monthly['data'].empty == False:
        print('\n\nLine Plot for: ', monthStart[1],'/',monthStart[0])
        createLinePlot(monthly['data'][column_map['date']], -1*monthly['data'][column_map['amount']].values, 8, 8);
# Out:
# Line Plot for:  08 / 2019
# Line Plot for:  09 / 2019
# Line Plot for:  10 / 2019
# Line Plot for:  11 / 2019

# %% [markdown]
# ### Line graphs for all categories

# %%
#libraries and data

import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

#Initialize the figure

plt.style.use('seaborn-darkgrid')

#create a color palette
palette = plt.get_cmap('Set1')

startDate = ''; endDate = '';

df = getDataForCategory(data.copy(), '', startDate , endDate, False)

expenses = []; size = 0;

plt.figure(figsize=(50,50))

num=0; 

for category in getCategories(): 
    num=num+1; 
    m = mergeDailyExpenseData(df.loc[df['Category'] == category])

    #if m['Amount'].empty == False:
    e= []
    if m.empty ==False:
        e = m['Amount'].values;



    if len(e)>size:
        size = e.size

    expenses.append(e)

    # Find the right spot on the plot
    plt.subplot(6,5, num)

    # Plot the lineplot
    plt.plot(list(range(0, len(e))), e, marker='', color=palette(num), linewidth=1.9, alpha=0.9, label=category)

    # Not ticks everywhere
    if num in range(7) :
        plt.tick_params(labelbottom='off')
    if num not in [1,4,7] :
        plt.tick_params(labelleft='off')

    # Add title
    plt.title(category, loc='left', fontsize=12, fontweight=0, color=palette(num) )

#general title

plt.suptitle("Categorical data: ", fontsize=13, fontweight=0, color='black', style='italic', y=1.02)
# Out:
# /home/work/.local/lib/python3.6/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# Text(0.5, 1.02, 'Categorical data: ')

# %% [markdown]
# ### Spaghetti Plot

# %%
# libraries and data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# style
plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(50,50))

# create a color palette
palette = plt.get_cmap('Set1')
 
# multiple line plot
num=0

df = getDataForCategory(data.copy(), '', startDate , endDate, False)

for category in getCategories(): 
    num=num+1; 
    m = mergeDailyExpenseData(df.loc[df['Category'] == category])

    #if m['Amount'].empty == False:
    e= []
    if m.empty ==False:
        e = m['Amount'].values;



    if len(e)>size:
        size = e.size

    expenses.append(e)
    
    # Plot the lineplot
    plt.plot(list(range(0, len(e))), e, marker='', color=palette(num), linewidth=1.9, alpha=0.9, label=category)
    
# Add legend
plt.legend(loc=2, ncol=10)
 
# Add titles
plt.title("A (bad) Spaghetti plot", loc='left', fontsize=12, fontweight=0, color='orange')
plt.xlabel("Money")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# ### Donut Plot

# %%
import pandas as pd
import re

import matplotlib.pyplot as plt

plt.figure(figsize=(25, 25))

c = getCategories();
categorical_expenditure = getTotalExpenditure(data)
startingRadius = 0.7 + (0.3* (len(c)-1))
#print(categorical_expenditure)
ce = categorical_expenditure['Expense']
total_expense = np.sum(ce)
#print(total_expense)

for i in range(len(ce)):
    ce[i] = int((ce[i]/total_expense)*100);
    textLabel = c[i] + ' ' + str(ce[i])
    remainingPie = 100 - ce[i]
    donut_sizes = [remainingPie, ce[i]]
    
    plt.text(0.01, startingRadius + 0.07, textLabel, horizontalalignment='center', verticalalignment='center')
    plt.pie(donut_sizes, radius=startingRadius, startangle=90, colors=['#d5f6da', '#5cdb6f'], wedgeprops={"edgecolor": "white", 'linewidth': 1})
    
    startingRadius-=0.3

# equal ensures pie chart is drawn as a circle (equal aspect ratio)
plt.axis('equal')

# create circle and place onto pie chart
circle = plt.Circle(xy=(0, 0), radius=0.35, facecolor='white')
plt.gca().add_artist(circle)
plt.show()
